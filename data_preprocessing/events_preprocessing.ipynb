# %% [markdown]
# # Event Dataset Preprocessing
#
# Using  two datasets from the city of Aarhus:
# - Set of cultural events from the municipality of Aarhus (June/2012 - July/2014)
# - Set of events hosted by libraries in Denmark (October/2013 - June/2015)

# %%
import tarfile
import pandas as pd
import os
import json
from pathlib import Path
import zipfile

# %% [markdown]
# ## Cultural events
#
# Edited:
# - named columns based on the information from the links
# - 3 columns that contained html code, static values

# %%
cultural_df = pd.read_csv('../data/cultural_events_aarhus.csv', sep=';')
cultural_df.head()
# Out:
#    Unnamed: 0      City                                         Name  \
# 0           1  Aarhus C                                KAMMERKONCERT
# 1           0  Aarhus C                   Sanne Salomonsen Hjem 2014
# 2           0  Aarhus C                 Jane & Shane og John Sheahan
# 3           0  Aarhus C  Scandinavian Saxophone Festival-Times Again
# 4           0  Aarhus C                                   H.P. Lange
#
#                                               Ticket               Price  \
# 0  http://www.billetlugen.dk/referer/?r=266abe1b7...  85.00 - 115.00 DKK
# 1  http://www.billetlugen.dk/referer/?r=266abe1b7...          295.00 DKK
# 2  http://www.billetlugen.dk/referer/?r=266abe1b7...          250.00 DKK
# 3  http://www.billetlugen.dk/referer/?r=266abe1b7...              Gratis
# 4  http://www.billetlugen.dk/referer/?r=266abe1b7...              Gratis
#
#    Unnamed: 5     ID              Room                 Date  \
# 0  1403593223  46773     Symfonisk Sal  2014-09-21T15:00:00
# 1  1398409215  42105         Store Sal  2014-04-24T20:00:00
# 2  1398495614  42979         Lille Sal  2014-04-25T19:30:00
# 3  1397718013  46785  Kammermusiksalen  2014-04-16T19:30:00
# 4  1397804412  45099            Caféen  2014-04-17T13:00:00
#
#                                           Website  Unnamed: 10   Type  \
# 0  http://www.musikhusetaarhus.dk/kalender/29048/          901  Musik
# 1  http://www.musikhusetaarhus.dk/kalender/31483/          230  Musik
# 2  http://www.musikhusetaarhus.dk/kalender/31803/          292  Musik
# 3  http://www.musikhusetaarhus.dk/kalender/29210/          554  Musik
# 4  http://www.musikhusetaarhus.dk/kalender/29289/          413  Musik
#
#                                                 Logo            Genre
# 0  http://static.billetlugen.dk/images/events/b/2...         Klassisk
# 1  http://static.billetlugen.dk/images/events/b/3...         Rock,Pop
# 2  http://static.billetlugen.dk/images/events/b/3...             Folk
# 3  http://static.billetlugen.dk/images/events/b/2...  Klassisk,Gratis
# 4  http://static.billetlugen.dk/images/events/b/2...   Koncert,Gratis

# %%
print('Cultural events info')
cultural_df.describe()
# Out:
# Cultural events info
#        Unnamed: 0    Unnamed: 5            ID  Unnamed: 10
# count  100.000000  1.000000e+02    100.000000   100.000000
# mean     0.580000  1.400963e+09  46812.800000   615.290000
# std      0.669388  2.934420e+06   2483.089046   186.379557
# min      0.000000  1.397200e+09  37691.000000   230.000000
# 25%      0.000000  1.398496e+09  46743.750000   571.250000
# 50%      1.000000  1.399921e+09  47376.000000   638.500000
# 75%      1.000000  1.403334e+09  47918.500000   677.500000
# max      4.000000  1.407308e+09  51709.000000   985.000000

# %% [markdown]
# ## Library Events
#
# Has location information

# %%
 
library_df = pd.read_csv('../data/aarhus_libraryEvents.csv', sep=',')
library_df.head()
# Out:
#    lid    city              endtime  \
# 0    1  Aarhus  2013-11-05 17:00:00
# 1   42  Viby J  2013-12-30 00:00:00
# 2    6   Beder  2014-02-27 21:00:00
# 3   55     Åby  2013-10-31 00:00:00
# 4    1  Aarhus  2014-04-18 11:30:00
#
#                                                title  \
# 0                         Lav din egen 'bogæder'\t\t
# 1  Keramiker Susanne Bidstrup udstiller på Viby B...
# 2                                         Ølsmagning
# 3  Susanne Butcher udstiller på Åby Bibliotek i o...
# 4                            International Playgroup
#
#                              url  price              changed  \
# 0  https://www.aakb.dk/node/8989      0  2013-11-04T11:53:11
# 1  https://www.aakb.dk/node/9235      0  2013-12-02T15:05:32
# 2  https://www.aakb.dk/node/9227     70  2014-01-24T11:01:24
# 3  https://www.aakb.dk/node/8920      0  2013-10-28T14:30:25
# 4  https://www.aakb.dk/node/9325      0  2013-12-10T16:45:18
#
#                                              content  zipcode  \
# 0  \n<p><img title="" src="https://www.aakb.dk/fi...     8000
# 1  \n<p>Susanne Bidstrup arbejder både med drejed...     8260
# 2  \n<p><img src="https://www.aakb.dk/files/conte...     8330
# 3  \n<p><img src="https://www.aakb.dk/files/conte...     8230
# 4  \n<p><img title="" src="https://www.aakb.dk/fi...     8000
#
#                    library                                           imageurl  \
# 0         Hovedbiblioteket  https://www.aakb.dk/files/list_images/bogmaerk...
# 1           Viby Bibliotek  https://www.aakb.dk/files/list_images/susanne_...
# 2  Beder-Malling Bibliotek  https://www.aakb.dk/files/list_images/oelsmagn...
# 3            Åby Bibliotek  https://www.aakb.dk/files/list_images/susanneb...
# 4         Hovedbiblioteket  https://www.aakb.dk/files/list_images/colourbo...
#
#                                               teaser                  street  \
# 0  Kom og vær med, når vi tirsdag eftermiddag lav...             Møllegade 1
# 1                            Inspirerende udstilling      Skanderborgvej 170
# 2        Kom til ølsmagning med en ægte ølentusiast!          Kirkebakken 41
# 3  Susanne Butcher er født i 1966, og er autodida...  Ludvig Feilbergs Vej 7
# 4  Aarhus Main Library in cooperation with UIC in...             Møllegade 1
#
#    status  longitude            starttime   latitude  _id    id  \
# 0       1  10.200179  2013-11-05 15:00:00  56.156617  258  8989
# 1       2  10.164431  2013-12-02 00:00:00  56.130402  379  9235
# 2       2  10.216045  2014-02-27 19:00:00  56.060321  371  9227
# 3       1  10.162515  2013-10-01 00:00:00  56.156438  233  8920
# 4       1  10.200179  2014-04-18 10:30:00  56.156617  416  9325
#
#             streamtime
# 0  2014-12-08 17:44:00
# 1  2014-12-08 17:44:00
# 2  2014-12-08 17:44:00
# 3  2014-12-08 17:44:00
# 4  2014-12-08 17:44:00

# %%
print('Cultural events info')
library_df.describe()
# Out:
# Cultural events info
#                lid        price      zipcode       status    longitude  \
# count  1548.000000  1548.000000  1548.000000  1548.000000  1548.000000
# mean     20.781008     3.989018  8191.196382     1.501938    10.178265
# std      18.232371    16.321210   161.665272     0.529049     0.053129
# min       1.000000     0.000000  8000.000000     0.000000     9.998690
# 25%       1.000000     0.000000  8000.000000     1.000000    10.162515
# 50%      15.000000     0.000000  8230.000000     2.000000    10.200179
# 75%      34.000000     0.000000  8260.000000     2.000000    10.200179
# max      55.000000   150.000000  8541.000000     2.000000    10.308101
#
#           latitude          _id            id
# count  1548.000000  1548.000000   1548.000000
# mean     56.161029   787.461240  10083.644703
# std       0.037195   448.632288   1031.650942
# min      56.042783     1.000000   7827.000000
# 25%      56.155665   401.750000   9298.750000
# 50%      56.156617   788.500000  10245.500000
# 75%      56.179458  1175.250000  10949.000000
# max      56.271071  1562.000000  11753.000000
